# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("project.csv")
belgium = df[df.Country == "Belgium"]
austria = df[df.Country == "Austria"]
# Out:
#      Gender  Age  Country  No_Household  Avg_Spend Food Snack Frozen_Food  \
# 2      Male   57  Austria             2         63  Yes    No         Yes
# 4      Male   51  Austria             3         70  Yes    No          No
# 43   Female   33  Austria             2         62  Yes   Yes          No
# 71     Male   59  Austria             2         45   No   Yes         Yes
# 81   Female   38  Austria             3         82  Yes    No         Yes
# ..      ...  ...      ...           ...        ...  ...   ...         ...
# 960  Female   37  Austria             2         89   No    No         Yes
# 972  Female   46  Austria             5         32  Yes   Yes         Yes
# 982  Female   53  Austria             1         30  Yes    No          No
# 993    Male   34  Austria             4         78   No   Yes          No
# 995  Female   39  Austria             4         16   No    No          No
#
#     Vegetables Seasoning Ingredients               Question_2     Question_3  \
# ...

# %%
male_count = austria[austria.Gender == "Male"].Gender.count()
female_count = austria[austria.Gender == "Female"].Gender.count()
df = pd.DataFrame(
    {
        "Gender": ["Male"],
        "Male": [male_count],
    }
)
df.plot(kind="hist")
plt.show()

df = pd.DataFrame(
    {
        "Gender": ["Female"],
        "Female": [female_count],
    }
)
df.plot(kind="hist")
plt.show()

# %%
male_count = belgium[belgium.Gender == "Male"].Gender.count()
female_count = belgium[belgium.Gender == "Female"].Gender.count()
df = pd.DataFrame(
    {
        "Gender": ["Male"],
        "Male": [male_count],
    }
)
df.plot(kind="hist")
plt.show()

df = pd.DataFrame(
    {
        "Gender": ["Female"],
        "Female": [female_count],
    }
)
df.plot(kind="hist")
plt.show()

# %%
austria["Age"].to_frame().boxplot()
plt.show()
austria["No_Household"].to_frame().boxplot()
plt.show()
austria["Avg_Spend"].to_frame().boxplot()
plt.show()

# %%
belgium["Age"].to_frame().boxplot()
plt.show()
belgium["No_Household"].to_frame().boxplot()
plt.show()
belgium["Avg_Spend"].to_frame().boxplot()
plt.show()
