# %%
for i in range(5):
    print("Shann")
# Out:
# Shann
# Shann
# Shann
# Shann
# Shann

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

article_read = pd.read_csv(
    "pandas_tutorial_read.csv",
    delimiter=";",
    names=["my_datetime", "event", "country", "user_id", "source", "topic"],
)
article_read
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# ...                   ...   ...        ...         ...      ...            ...
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia
#
# [1795 rows x 6 columns]

# %%
article_read.head(12)  # get the first n number of data
# Out:
#             my_datetime event    country     user_id   source          topic
# 0   2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1   2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2   2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3   2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4   2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5   2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6   2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7   2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8   2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9   2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10  2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
article_read.tail(7)  # get the last n number of data
# Out:
#               my_datetime event    country     user_id   source          topic
# 1788  2018-01-01 23:55:04  read  country_7  2458153049  AdWords         Europe
# 1789  2018-01-01 23:56:42  read  country_4  2458153050  AdWords           Asia
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia

# %%
article_read.sample(6)
# Out:
#               my_datetime event    country     user_id   source          topic
# 1620  2018-01-01 21:56:30  read  country_7  2458152881   Reddit  South America
# 66    2018-01-01 01:00:20  read  country_6  2458151327  AdWords           Asia
# 1130  2018-01-01 15:08:32  read  country_5  2458152391   Reddit         Europe
# 1246  2018-01-01 16:53:16  read  country_7  2458152507  AdWords  South America
# 214   2018-01-01 03:02:25  read  country_2  2458151475      SEO  North America
# 61    2018-01-01 00:55:48  read  country_7  2458151322  AdWords      Australia

# %%
article_read[["country", "user_id"]]  # dataframe format
# Out:
#         country     user_id
# 0     country_7  2458151261
# 1     country_7  2458151262
# 2     country_7  2458151263
# 3     country_7  2458151264
# 4     country_8  2458151265
# ...         ...         ...
# 1790  country_2  2458153051
# 1791  country_8  2458153052
# 1792  country_6  2458153053
# 1793  country_7  2458153054
# 1794  country_5  2458153055
#
# [1795 rows x 2 columns]

# %%
article_read.user_id  # series format
# Out:
# 0       2458151261
# 1       2458151262
# 2       2458151263
# 3       2458151264
# 4       2458151265
#            ...
# 1790    2458153051
# 1791    2458153052
# 1792    2458153053
# 1793    2458153054
# 1794    2458153055
# Name: user_id, Length: 1795, dtype: int64

# %%
article_read[
    article_read.source == "SEO"
]  # to get only a specific value from a specific column
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# ...                   ...   ...        ...         ...    ...            ...
# 1772  2018-01-01 23:45:58  read  country_7  2458153033    SEO  South America
# 1777  2018-01-01 23:49:52  read  country_5  2458153038    SEO  North America
# 1779  2018-01-01 23:51:25  read  country_4  2458153040    SEO  South America
# 1784  2018-01-01 23:54:03  read  country_2  2458153045    SEO  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052    SEO           Asia
#
# [346 rows x 6 columns]

# %%
article_read[article_read.country == "country_8"]  # same as above
# Out:
#               my_datetime event    country     user_id   source          topic
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277      SEO  North America
# 45    2018-01-01 00:37:35  read  country_8  2458151306  AdWords           Asia
# 59    2018-01-01 00:53:05  read  country_8  2458151320   Reddit           Asia
# 72    2018-01-01 01:04:22  read  country_8  2458151333      SEO  North America
# ...                   ...   ...        ...         ...      ...            ...
# 1760  2018-01-01 23:33:54  read  country_8  2458153021  AdWords           Asia
# 1768  2018-01-01 23:44:52  read  country_8  2458153029   Reddit  South America
# 1773  2018-01-01 23:46:13  read  country_8  2458153034   Reddit           Asia
# 1780  2018-01-01 23:51:46  read  country_8  2458153041  AdWords         Africa
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
#
# [153 rows x 6 columns]

# %%
article_read.head()[
    ["country", "user_id"]
]  # first five records of only specified columns
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
article_read[article_read.country == "country_2"][
    ["user_id", "country", "topic"]
].head()
# Out:
#        user_id    country   topic
# 6   2458151267  country_2  Europe
# 13  2458151274  country_2  Europe
# 17  2458151278  country_2    Asia
# 19  2458151280  country_2    Asia
# 20  2458151281  country_2    Asia

# %%
article_read[article_read.source == "Reddit"][article_read.topic == "Asia"][
    ["user_id", "source", "topic"]
].head(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16576\3862206101.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   article_read[article_read.source == 'Reddit'][article_read.topic == 'Asia'][['user_id', 'source', 'topic']].head(10)
#        user_id  source topic
# 12  2458151273  Reddit  Asia
# 17  2458151278  Reddit  Asia
# 19  2458151280  Reddit  Asia
# 20  2458151281  Reddit  Asia
# 23  2458151284  Reddit  Asia
# 28  2458151289  Reddit  Asia
# 29  2458151290  Reddit  Asia
# 38  2458151299  Reddit  Asia
# 39  2458151300  Reddit  Asia
# 42  2458151303  Reddit  Asia

# %%
zoo = pd.read_csv("zoo.csv", delimiter=",")
zoo.head(7)
# Out:
#      animal  uniq_id  water_need
# 0  elephant     1001         500
# 1  elephant     1002         600
# 2  elephant     1003         550
# 3     tiger     1004         300
# 4     tiger     1005         320
# 5     tiger     1006         330
# 6     tiger     1007         290

# %%
zoo.count()[["animal", "water_need"]]
# Out:
# animal        22
# water_need    22
# dtype: int64

# %%
zoo.water_need.sum()
# Out:
# 7650

# %%
zoo["water_need"].max()
# Out:
# 600

# %%
zoo["water_need"].min()
# Out:
# 80

# %%
zoo["water_need"].mean()
# Out:
# 347.72727272727275

# %%
zoo["water_need"].median()
# Out:
# 325.0

# %%
zoo.groupby("animal").mean()[["water_need"]]
# Out:
#           water_need
# animal
# elephant  550.000000
# kangaroo  416.666667
# lion      477.500000
# tiger     310.000000
# zebra     184.285714

# %%
zoo.groupby("animal").mean().water_need
# Out:
# animal
# elephant    550.000000
# kangaroo    416.666667
# lion        477.500000
# tiger       310.000000
# zebra       184.285714
# Name: water_need, dtype: float64

# %%
zoo = pd.read_csv("zoo.csv", delimiter=",")
zoo_eats = pd.read_csv("zoo_eats.csv", delimiter=",")

# %%
zoo
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
zoo_eats
# Out:
#      animal        food
# 0  elephant  vegetables
# 1     tiger        meat
# 2  kangaroo  vegetables
# 3     zebra        meat
# 4   giraffe  vegetables

# %%
zoo.merge(zoo_eats, how="inner")
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200        meat
# 9      zebra     1010         220        meat
# 10     zebra     1011         240        meat
# 11     zebra     1012         230        meat
# 12     zebra     1013         220        meat
# 13     zebra     1014         100        meat
# 14     zebra     1015          80        meat
# 15  kangaroo     1020         410  vegetables
# 16  kangaroo     1021         430  vegetables
# 17  kangaroo     1022         410  vegetables

# %%
zoo.merge(zoo_eats, how="outer")
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant   1001.0       500.0  vegetables
# 1   elephant   1002.0       600.0  vegetables
# 2   elephant   1003.0       550.0  vegetables
# 3      tiger   1004.0       300.0        meat
# 4      tiger   1005.0       320.0        meat
# 5      tiger   1006.0       330.0        meat
# 6      tiger   1007.0       290.0        meat
# 7      tiger   1008.0       310.0        meat
# 8      zebra   1009.0       200.0        meat
# 9      zebra   1010.0       220.0        meat
# 10     zebra   1011.0       240.0        meat
# 11     zebra   1012.0       230.0        meat
# 12     zebra   1013.0       220.0        meat
# 13     zebra   1014.0       100.0        meat
# 14     zebra   1015.0        80.0        meat
# 15      lion   1016.0       420.0         NaN
# 16      lion   1017.0       600.0         NaN
# 17      lion   1018.0       500.0         NaN
# 18      lion   1019.0       390.0         NaN
# ...

# %%
zoo.sort_values("water_need")
# Out:
#       animal  uniq_id  water_need
# 14     zebra     1015          80
# 13     zebra     1014         100
# 8      zebra     1009         200
# 9      zebra     1010         220
# 12     zebra     1013         220
# 11     zebra     1012         230
# 10     zebra     1011         240
# 6      tiger     1007         290
# 3      tiger     1004         300
# 7      tiger     1008         310
# 4      tiger     1005         320
# 5      tiger     1006         330
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 15      lion     1016         420
# 20  kangaroo     1021         430
# 17      lion     1018         500
# 0   elephant     1001         500
# 2   elephant     1003         550
# 16      lion     1017         600
# 1   elephant     1002         600

# %%
zoo.sort_values("water_need", ascending=False)
# Out:
#       animal  uniq_id  water_need
# 1   elephant     1002         600
# 16      lion     1017         600
# 2   elephant     1003         550
# 0   elephant     1001         500
# 17      lion     1018         500
# 20  kangaroo     1021         430
# 15      lion     1016         420
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 18      lion     1019         390
# 5      tiger     1006         330
# 4      tiger     1005         320
# 7      tiger     1008         310
# 3      tiger     1004         300
# 6      tiger     1007         290
# 10     zebra     1011         240
# 11     zebra     1012         230
# 9      zebra     1010         220
# 12     zebra     1013         220
# 8      zebra     1009         200
# 13     zebra     1014         100
# 14     zebra     1015          80

# %%
zoo.sort_values(by=["animal", "water_need"], ascending=True).reset_index()
# Out:
#     index    animal  uniq_id  water_need
# 0       0  elephant     1001         500
# 1       2  elephant     1003         550
# 2       1  elephant     1002         600
# 3      19  kangaroo     1020         410
# 4      21  kangaroo     1022         410
# 5      20  kangaroo     1021         430
# 6      18      lion     1019         390
# 7      15      lion     1016         420
# 8      17      lion     1018         500
# 9      16      lion     1017         600
# 10      6     tiger     1007         290
# 11      3     tiger     1004         300
# 12      7     tiger     1008         310
# 13      4     tiger     1005         320
# 14      5     tiger     1006         330
# 15     14     zebra     1015          80
# 16     13     zebra     1014         100
# 17      8     zebra     1009         200
# 18      9     zebra     1010         220
# 19     12     zebra     1013         220
# 20     11     zebra     1012         230
# 21     10     zebra     1011         240

# %%
zoo.sort_values(by=["animal", "water_need"], ascending=True).reset_index(
    drop=True
)
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1003         550
# 2   elephant     1002         600
# 3   kangaroo     1020         410
# 4   kangaroo     1022         410
# 5   kangaroo     1021         430
# 6       lion     1019         390
# 7       lion     1016         420
# 8       lion     1018         500
# 9       lion     1017         600
# 10     tiger     1007         290
# 11     tiger     1004         300
# 12     tiger     1008         310
# 13     tiger     1005         320
# 14     tiger     1006         330
# 15     zebra     1015          80
# 16     zebra     1014         100
# 17     zebra     1009         200
# 18     zebra     1010         220
# 19     zebra     1013         220
# 20     zebra     1012         230
# 21     zebra     1011         240

# %%
zoo.merge(zoo_eats, how="left")
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200        meat
# 9      zebra     1010         220        meat
# 10     zebra     1011         240        meat
# 11     zebra     1012         230        meat
# 12     zebra     1013         220        meat
# 13     zebra     1014         100        meat
# 14     zebra     1015          80        meat
# 15      lion     1016         420         NaN
# 16      lion     1017         600         NaN
# 17      lion     1018         500         NaN
# 18      lion     1019         390         NaN
# ...

# %%
zoo.merge(zoo_eats, how="left").fillna("meat")
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200        meat
# 9      zebra     1010         220        meat
# 10     zebra     1011         240        meat
# 11     zebra     1012         230        meat
# 12     zebra     1013         220        meat
# 13     zebra     1014         100        meat
# 14     zebra     1015          80        meat
# 15      lion     1016         420        meat
# 16      lion     1017         600        meat
# 17      lion     1018         500        meat
# 18      lion     1019         390        meat
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        "name": ["john", "mary", "peter", "jeff", "bill", "lisa", "jose"],
        "age": [23, 78, 22, 19, 45, 33, 20],
        "gender": ["M", "F", "M", "M", "M", "F", "M"],
        "state": [
            "california",
            "dc",
            "california",
            "dc",
            "california",
            "texas",
            "texas",
        ],
        "num_children": [2, 0, 0, 3, 2, 1, 4],
        "num_pets": [5, 1, 0, 5, 2, 2, 3],
    }
)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df = pd.DataFrame({
#       2     'name':['john','mary','peter','jeff','bill','lisa','jose'],
#       3     'age':[23,78,22,19,45,33,20],
#       4     'gender':['M','F','M','M','M','F','M'],
#       5     'state':['california','dc','california','dc','california','texas','texas'],
#       6     'num_children':[2,0,0,3,2,1,4],
#       7     'num_pets':[5,1,0,5,2,2,3]
#       8 })
#       9 df
#
# NameError: name 'pd' is not defined

# %%
df.plot(kind="scatter", x="num_children", y="age", color="green")
plt.show()

# %%
df.plot(kind="bar", x="name", y="num_pets", color="green")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df.plot(kind = 'bar', x = 'name', y = 'num_pets', color = 'green')
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
ax = plt.gca()
df.plot(kind="line", x="name", y="num_children", ax=ax)
df.plot(kind="line", x="name", y="num_pets", ax=ax)
plt.savefig("mygraph.png")

# %%
df.plot(kind="pie", x="name", y="num_pets")
plt.show()

# %%
labels = "john", "mary", "peter", "jeff", "bill", "lisa", "jose"
df.plot(kind="pie", x="name", y="num_pets", labels=labels)
plt.show()

# %%
labels = "john", "mary", "peter", "jeff", "bill", "lisa", "jose"
df.plot(kind="pie", x="name", y="num_pets", labels=labels, legend=False)
plt.show()

# %%
labels = "john", "mary", "peter", "jeff", "bill", "lisa", "jose"
df.plot(
    kind="pie",
    x="name",
    y="num_pets",
    labels=labels,
    legend=False,
    table=df,
    figsize=(8, 8),
    explode=(0, 0.2, 0, 0, 0, 0, 0),
)
plt.show()

# %%
ax = df[["age"]].plot(kind="hist", bins=[0, 20, 40, 60, 80, 100], rwidth=0.9)
ax.set(title="Superman", xlabel="Range of ages", ylabel="Total amount")
plt.show()
